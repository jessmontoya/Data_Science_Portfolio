# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
import re

# %%
url = 'https://webpoint.usawaterpolo.com/wp15/Companies/Clubs.wp'
response = get(url)

# %%
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>USA Water Polo Clubs</title>
# <meta charset="utf-8" />
# <meta name="keywords" content="">
# <meta name="description" content="">
# <meta name="apple-mobile-web-app-capable" content="yes">
# <meta name="apple-mobile-web-app-status-bar-style" content="black">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <link rel="stylesheet" type="text/css" media="screen" href="/wp_Media/css/

# %%
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
print(html_soup.prettify()[:20000])
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    USA Water Polo Clubs
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="" name="keywords"/>
#   <meta content="" name="description"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="/wp_Media/css/Normalize.css?version=2017_06_19" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/Spinner.css?version=2018_06_09" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/jquery-ui-1.8.23.custom.css?version=2018_09_05" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/PageElements.css?version=2019_12_6" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/FE_Style.css?version=2019_05_12" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/Print.css?version=2018_09_05" media="print" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/webpoint_icons.css?version=2019_3_28" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/jquery.featherlight.css" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/jquery-ui-timepicker-addon.css" rel="stylesheet" type="text/css"/>
#    <link href="/wp_Media/css/formfields.css" media="screen" rel="stylesheet" type="text/css"/>
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#    <script src="/wp15_JS/Validators.js?version=2018_05_15">
#    </script>
#    <script src="/wp15_JS/CkFields.js?version=2019_10_10">
#    </script>
#    <script src="/wp15_JS/IntlAddressNew.js">
#    </script>
#    <script src="/wp15_JS/Forms/ValidateSrch.js">
#    </script>
#    <script src="/wp15_JS/Misc.js?version=2018_05_29">
#    </script>
#    <script src="/wp15_JS/TrxLibrary.js?version=2018_05_30">
#    </script>
#    <script src="/wp15_JS/AJAXData.js?version=2018_06_11">
#    </script>
#    <script src="/wp15_JS/Forms/ValidateCC.js?version=2018_05_30">
#    </script>
#    <script src="https://www.googletagmanager.com/gtag/js?id=UA-8720673-4">
#    </script>
#    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js">
#    </script>
#    <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js">
#    </script>
#    <script src="/wp15_JS/JQuery/multiselect.js">
#    </script>
#    <script src="/wp15_JS/JQuery/multiselect_filter.js">
#    </script>
#    <script src="/wp15_JS/JQuery/jquery.featherlight.js">
#    </script>
#    <script src="/wp15_JS/JQuery/jquery-ui-timepicker-addon.js">
#    </script>
#    <script src="/wp15_JS/JQuery/cookie.js">
#    </script>
#    <script src="/wp15_JS/JQuery/accordian_FE_Menu.js">
#    </script>
#    <script src="/wp15_JS/AccordionMenu.js?version=2014_06_09_02">
#    </script>
#    <script>
#     if (parent.frames.length > 0) {parent.location.href = location.href;}
#
# window.dataLayer = window.dataLayer || [];
#  function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-8720673-4');
#
# function verifyGoDaddySSLSeal() {
# 	window.open('https://seal.godaddy.com/verifySeal?sealID=CpnYkERtLP8KUYUsFQeenJ3jAql0hULjftcHloXPWtLKuBa0mEp1Y5T4de5F', 'SealVerfication', 'location=yes,status=yes,resizable=yes,scrollbars=no,width=592,height=433');
# }
#
# $(function($) {
# 	$('.smultiselectbox').multiselect({selectedList: 8,position: {my: 'left bottom',at: 'left top'}}).multiselectfilter();
# 	$.datepicker.setDefaults({ changeMonth:true, changeYear:true, numberOfMonths:1, yearRange:'-15:+2',
# 	//	showOn: 'both', buttonText: "<i class='fa fa-calendar'></i>", buttonImage: "/wp_media/css/images/calendar.gif", buttonImageOnly: true,
# 	});
# });
#    </script>
#   </meta>
#  </head>
#  <body class="drawer drawer--left drawer--navbarTopGutter">
#   <div class="container">
#    <div class="noprint">
#     <div id="site-header">
#      <div class="noprint" id="global-nav">
#       <div id="teamusa-nav">
#        <font color="#999999">
#         <span class="date">
#          <font color="#CC0000" face="Verdana">
#           &gt;
#           <a class="mem" href="/wp15/IntraLock/Login.wp">
#            <i class="fa fa-lock" title="">
#            </i>
#            Member Login
#           </a>
#          </font>
#          <font color="#999999" face="Verdana">
#           |
#          </font>
#          <font color="#CC0000" face="Verdana">
#           &gt;
#           <a class="mem" href="/wp/Memberships/Join.wp">
#            <i class="fa fa-user-plus" title="Add Contact">
#            </i>
#            Join USA Water Polo
#           </a>
#          </font>
#         </span>
#        </font>
#       </div>
#       <div id="social-links">
#        <a class="instagram" href="https://instagram.com/usawp" target="_blank">
#        </a>
#        <a class="twitter" href="https://twitter.com/usawp" target="_blank">
#        </a>
#        <a class="facebook" href="https://www.facebook.com/usawp" target="_blank">
#        </a>
#       </div>
#      </div>
#      <div id="ngb-header" style="width:100%;min-height:100px;">
#       <h1 style="text-align:center">
#        <a href="http://www.usawaterpolo.org" style="float:left;" target="_blank">
#         <img src="/media/ClientLogo.png" style="max-height: 95px;"/>
#        </a>
#        <span>
#         USA
#        </span>
#        Water
#        <a href="https://goo.gl/kcuNMC" style="float:right;padding-top:10px;padding-right:10px;" target="_blank">
#         <img src="/Files/Org_Images/Kap72.png" style="max-height: 95px;"/>
#        </a>
#        Polo
#       </h1>
#      </div>
#     </div>
#    </div>
#    <div id="site-content">
#     <div class="noprint">
#      <div id="section-header">
#      </div>
#     </div>
#     <div class="span-4 noprint" id="section-menu">
#      <ul class="menu-v" id="menu-1">
#       <li class="top-level">
#        <a href="/Welcome.wp">
#         <span>
#          <b>
#           <i class="fa fa-home" title="">
#           </i>
#           USA Water Polo
#          </b>
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="/wp/Memberships/Join.wp">
#         Join USA Water Polo!
#        </a>
#       </li>
#       <li>
#        <a class="" href="/wp15/IntraLock/Login.wp?TargetPath=/wp/Memberships/Join.wp" rel="external">
#         Renew Your Membership
#        </a>
#       </li>
#       <li>
#        <a class="" href="/wp15/IntraLock/Login.wp?TargetPath=/wp15/Companies/Clubs.wp" rel="external">
#         <i class="fa fa-lock" title="">
#         </i>
#         Login
#        </a>
#       </li>
#       <li>
#        <a href="/wp15/Intralock/ForgotPwd.wp">
#         <i class="fa fa-question-circle" title="">
#         </i>
#         Forgot Password?
#        </a>
#       </li>
#       <li class="top-level">
#        <a href="#" onclick="return false;">
#         <b>
#          USAWP Events
#         </b>
#        </a>
#        <li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_TypeID=1">
#           Conference Events
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_CategoryID=7,8,86,90">
#           National Events
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_CategoryID=6">
#           Regional Events
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_TypeID=3,6,8,9&amp;evt_CategoryID_NOT=2,4,6,7,8,10,14,90,86&amp;rf=Oo">
#           Sanctioned Events
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_TypeID=6,3&amp;evt_CategoryID=2,4">
#           ODP Camps
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_CategoryID=13">
#           Coach/Referee Schools
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?evt_TypeID=6&amp;evt_CategoryID=5,82">
#           Camps/Clinics
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?aevt_CategoryID=96&amp;evt_ParentEventID=27833">
#           Splashball Programs
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Events.wp?isMasters=1">
#           Masters Events
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Events2/Tickets.wp">
#           <b>
#            <i class="fa fa-ticket" title="">
#            </i>
#            Event Tickets
#           </b>
#          </a>
#         </li>
#         <li>
#          <a class="parent" href="#" onclick="return false;">
#           <span style="font-weight:bolder;">
#            <i class="fa fa-water" title="">
#            </i>
#            Splashball
#           </span>
#          </a>
#          <ul class="menu-v">
#           <li>
#            <a href="/website/splashball.wp">
#             Splashball Information
#            </a>
#           </li>
#           <li>
#            <a href="/wp15/Events2/Events.wp?aevt_CategoryID=96&amp;evt_ParentEventID=27833">
#             Find Splashball Programs
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="top-level">
#          <a href="#" onclick="return false;">
#           <b>
#            Other Links
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Companies/Clubs.wp">
#           <i class="fa fa-compass" title="">
#           </i>
#           Find a Club
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Companies/Clubs.wp?CustomCompanyGroup1ID=1&amp;ReportTitle=Masters+Clubs&amp;submit=Go">
#           Masters Programs
#          </a>
#         </li>
#         <li>
#          <a class="parent" href="#" onclick="return false;">
#           <span style="font-weight:bolder;">
#            <i class="fa fa-list-alt" title="">
#            </i>
#            Member Benefits
#           </span>
#          </a>
#          <ul class="menu-v">
#           <li>
#            <a href="https://usawaterpolo.org/sports/2018/11/28/membership-benefits-html.aspx" onclick="if(!confirm('This link will redirect you to the USA Water Polo website.\nPlease return to this tab to access the membership &amp; event database.'))return false;" target="_blank">
#             Membership Benefits
#            </a>
#           </li>
#           <li>
#            <a href="https://usawaterpolo.org/sports/2018/11/28/membership-benefits-html.aspx" onclick="if(!confirm('This link will redirect you to the USA Water Polo website.\nPlease return to this tab to access the membership &amp; event database.'))return false;" target="_blank">
#             Sponsored Benefits
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="https://usawaterpolo.org/sports/2018/12/18/clubs.aspx" onclick="if(!confirm('This link will redirect you to the USA Water Polo website.\nPlease return to this tab to access the membership &amp; event database.'))return false;" target="_blank">
#           <b>
#            Club Registration
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Products/Catalog.wp?prd_CategoryID=6">
#           <b>
#            Member Only Products
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp/Transactions/Donate.wp">
#           <b>
#            Contribute
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="https://usawaterpolo.org/sports/2018/11/28/membership-membership-forms-html.aspx" onclick="if(!confirm('This link will redirect you to the USA Water Polo website.\nPlease return to this tab to access the membership &amp; event database.'))return false;" target="_blank">
#           <b>
#            Membership Forms
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Forum/Topic.wp?msg_TopicID=35">
#           <b>
#            Coach Job Postings
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp15/Forum/Topic.wp?msg_TopicID=85993">
#           <b>
#            Masters Forum
#           </b>
#          </a>
#         </li>
#         <li>
#          <a href="/wp/Email/PrivacyPolicy.wp">
#           Privacy Policy
#          </a>
#         </li>
#         <div class="center pad-10">
#         </div>
#        </li>
#       </li>
#      </ul>
#      <div id="brand-logos">
#       <script async="" src="https://cdn.ywxi.net/js/1.js" type="text/javascript">
#       </script>
#       <div id="GoDaddySSLSeal">
#        <img onclick="verifyGoDaddySSLSeal();" src="/wp_Media/Images/Godaddy_Seal.gif"/>
#       </div>
#      </div>
#     </div>
#     <div class="span-25" id="page-content">
#      <!------------------- END HEADER ----------->
#      <div class="spinner_off" id="wp_spinner">
#       <div class="spinner">
#       </div>
#      </div>
#      <table cellpadding="3" class="reporttable">
#       <tr class="pagetitlerow">
#        <td>
#         USA Water Polo Clubs
#        </td>
#       </tr>
#      </table>
#      <form action="/wp15/Companies/Clubs.wp" id="wp_ClubSrch" method="post" name="ShowClubs">
#      </form>
#      <input name="wp_ClientOrgID" type="hidden" value=""/>
#      <div class="flex-container flex-wrap push-100">
#       <div class="flex-container flex-wrap push-100">
#        <div class="col pad-10">
#         <tr>
#          <td>
#           Zone
#          </td>
#          <td>
#           <select class="selectbox" id="CompanyParentID" name="CompanyParentID">
#            <option value="">
#             -Select One-
#            </option>
#            <option value="10008">
#             Central California Zone
#            </option>
#            <option value="10011">
#             Coastal California Zone
#            </option>
#            <option value="17972">
#             International Zone
#            </option>
#            <option value="10003">
#             Midwest Zone
#            </option>
#            <option value="10010">
#             Mountain Zone
#            </option>
#            <option value="1795">
#             Northeast Zone
#            </option>
#            <option value="10005">
#             Pacific Northwest &amp; Hawaii Zone
#            </option>
#            <option value="10009">
#             Pacific Southwest Zone
#            </option>
#            <option value="10006">
#             Pacific Zone
#            </option>
#            <option value="10002">
#             Southeast Zone
#            </option>
#            <option value="10007">
#             Southern Pacific Zone
#            </option>
#            <option value="10004">
#             Southwest Zone
#            </option>
#           </select>
#          </td>
#         </tr>
#        </div>
#        <div class="col pad-10">
#         <tr>
#          <td>
#           Club Name
#          </td>
#          <td>
#           <input class="inputbox" id="CompanyName" maxlength="50" name="CompanyName" size="30" type="text" value=""/>
#          </td>
#         </tr>
#        </div>
#       </div>
#       <div class="flex-container flex-wrap push-100">
#        <div class="col pad-10">
#         <tr>
#          <td>
#           State
#          </td>
#          <td>
#           <select class="selectbox" id="CompanyState" name="CompanyState">
#            <option value="">
#             -Select One-
#            </option>
#            <option value="AL">
#             Alabama
#            </option>
#            <option value="AK">
#             Alaska
#            </option>
#            <option value="AZ">
#             Arizona
#            </option>
#            <option value="AR">
#             Arkansas
#            </option>
#            <option value="CA">
#             California
#            </option>
#            <option value="CO">
#             Colorado
#            </option>
#            <option value="CT">
#             Connecticut
#            </option>
#            <option value="DE">
#             Delaware
#            </option>
#            <option value="DC">
#             Dist. of Columbia
#            </option>
#            <option value="FL">
#             Florida
#            </option>
#            <option value="GA">
#             Georgia
#            </option>
#            <option value="HI">
#             Hawaii
#            </option>
#            <option value="ID">
#             Idaho
#            </option>
#            <option value="IL">
#             Illinois
#            </option>
#            <option value="IN">
#             Indiana
#            </option>
#            <option value="IA">
#             Iowa
#            </option>
#            <option value="KS">
#             Kansas
#            </option>
#            <option value="KY">
#             Kentucky
#            </option>
#            <option value="LA">
#             Louisiana
#            </option>
#            <option value="ME">
#             Maine
#            </option>
#            <option value="MD">
#             Maryland
#            </option>
#            <option value="MA">
#             Massachusetts
#            </option>
#            <option value="MI">
#             Michigan
#            </option>
#            <option value="MN">
#             Minnesota
#            </option>
#            <option value="MS">
#             Mississippi
#            </option>
#            <option value="MO">
#             Missouri
#            </option>
#            <option value="MT">
#             Montana
#            </option>
#            <option value="NE">
#             Nebraska
#            </option>
#            <option value="NV">
#             Nevada
#            </option>
#            <option value="NH">
#             New Hampshire
#            </option>
#            <option value="NJ">
#             New Jersey
#            </option>
#            <option value="NM">
#             New Mexico
#            </option>
#            <option value="NY">
#             New York
#            </option>
#            <option value="NC">
#             North Carolina
#            </option>
#            <option value="ND">
#             North Dakota
#            </option>
#            <option value="OH">
#             Ohio
#            </option>
#            <option value="OK">
#             Oklahoma
#            </option>
#            <option value="OR">
#             Oregon
#            </option>
#            <option value="PA">
#             Pennsylvania
#            </option>
#            <option value="RI">
#             Rhode Island
#            </option>
#            <option value="SC">
#             South Carolina
#            </option>
#            <option value="SD">
#             South Dakota
#            </option>
#            <option value="TN">
#             Tennessee
#            </option>
#            <option value="TX">
#             Texas
#            </option>
#            <option value="UT">
#             Utah
#            </option>
#            <option value="VT">
#             Vermont
#            </option>
#            <option value="VA">
#             Virginia
#            </option>
#            <option value="WA">
#             Washington
#            </option>
#            <option value="WV">
#             West Virginia
#            </option>
#            <option value="WI">
#             Wisconsin
#            </option>
#            <option value="WY">
#             Wyoming
#            </option>
#            <option value="AB">
#             Alberta
#            </option>
#            <option value="BC">
#             British Columbia
#            </option>
#            <option value="MB">
#             Manitoba
#            </option>
#            <option value="NB">
#             New Brunswick
#            </option>
#            <option value="NL">
#             Newfoundland
#            </option>
#            <option value="NT">
#             Northwest Territories
#            </option>
#            <option value="NS">
#             Nova Scotia
#            </option>
#            <option value="NU">
#             Nunavut
#            </option>
#            <option value="ON">
#             Ontario
#            </option>
#            <option value="PE">
#             Prince Edward Island
#            </option>
#            <option value="QC">
#             Quebec
#            </option>
#            <option value="SK">
#             Saskatchewan
#            </option>
#            <option value="YT">
#             Yukon
#            </option>
#           </select>
#          </td>
#         </tr>
#        </div>
#        <div class="flex-container push-70">
#         <div class="col pad-10">
#          <tr>
#           <td>
#            Zip Code
#           </td>
#           <td>
#            <input class="inputbox" id="geo_Zip" maxlength="12" name="geo_Zip" size="9" type="text" value=""/>
#           </td>

# %%
print(html_soup.title)
# Out:
# <title>USA Water Polo Clubs</title>

# %%
options = html_soup.find("select", attrs={"id":"CompanyParentID"})
option_list = options.find_all("option")

# %%
option_list
# Out:
# [<option value="">-Select One-</option>,
#  <option value="10008">Central California Zone</option>,
#  <option value="10011">Coastal California Zone</option>,
#  <option value="17972">International Zone</option>,
#  <option value="10003">Midwest Zone</option>,
#  <option value="10010">Mountain Zone</option>,
#  <option value="1795">Northeast Zone</option>,
#  <option value="10005">Pacific Northwest &amp; Hawaii Zone</option>,
#  <option value="10009">Pacific Southwest Zone</option>,
#  <option value="10006">Pacific Zone</option>,
#  <option value="10002">Southeast Zone</option>,
#  <option value="10007">Southern Pacific Zone</option>,
#  <option value="10004">Southwest Zone</option>]

# %%
zones = []
for option in option_list[1:]:
    zones.append(option.attrs['value'])

# %%
zones
# Out:
# ['10008',
#  '10011',
#  '17972',
#  '10003',
#  '10010',
#  '1795',
#  '10005',
#  '10009',
#  '10006',
#  '10002',
#  '10007',
#  '10004']

# %%
clubs = []

for zone in zones:
    payload = {
    'CompanyParentID': zone,
    'CompanyName':'',
    'CompanyState':'',
    'geo_Zip':'',
    'geo_Miles':'',
    'CustomCompanyGroup1':'',
    'Submit':'Go'
    }
    
    r = requests.post(url, data=payload)
    r_soup = BeautifulSoup(r.text, 'html.parser')
    
    club_info = r_soup.find("div", attrs={"class":"mobilelist fe-list-clubs"})
    
    for li in club_info.find_all("li"):
        club = {}
        club['club_name'] = li.h3.text
        if li.find("p", attrs={"class":None}):
            club['club_loc'] = li.find("p", attrs={"class":None}).text
        else: 
            club['club_loc'] = "Unknown"
        club['club_id'] = li.find("div", attrs={"class":"pad-5 org-icons-container"}).text
        club['club_zone'] = zone
        clubs.append(club)

# %%
clubs
# Out:
# [{'club_name': ' 209 Water Polo Club',
#   'club_loc': 'Primary Pool:\r\n\t\t\t\
\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 30299\n\xa0\r\n\t\t\t\t\r\n\t\t\t',
#   'club_zone': '10004'}]

# %%
clubs_df = pd.DataFrame(clubs)

# %%
clubs_df.head(20)
# Out:
#                                 club_name  \
# 0                     209 Water Polo Club
# 1                  A-Town Water Polo Club
# 2                  Alumni Water Polo Club
# 3          American River Water Polo Club
# 4                Arroyo Grande Water Polo
# 5                            Asa Aquatics
# 6             Bakersfield Water Polo Club
# 7              BarDown Water Polo Academy
# 8                  Blazer Water Polo Club
# 9                 Bulldog Water Polo Club
# 10                        California Gold
# 11                 California Republic SC
# 12   Capital City Masters Water Polo Club
# 13           Central Tsunami Aquatic Club
# 14         Central Valley Water Polo Club
# 15                 Clovis Water Polo Club
# 16                       Concord Aquatics
# 17                  Davis Water Polo Club
# 18                  Dixon Water Polo Club
# 19                          Echo Aquatics
#
#                                              club_loc  \
# 0   Primary Pool:\r\n\t\t\t\tBuhach Colony High Sc...
# 1   Primary Pool:\r\n\t\t\t\tAtascadero High Schoo...
# 2   Primary Pool:\r\n\t\t\t\tGranite Bay High Scho...
# 3   Primary Pool:\r\n\t\t\t\tRio Americano High Sc...
# 4   Primary Pool:\r\n\t\t\t\tArroyo Grande High Sc...
# 5   Primary Pool:\r\n\t\t\t\tEl Capitan High Schoo...
# 6   Primary Pool:\r\n\t\t\t\tGarces Memorial High ...
# 7   Primary Pool:\r\n\t\t\t\tCSU Stanislaus\r\n\t\...
# 8   Primary Pool:\r\n\t\t\t\tGolden West High Scho...
# 9   Primary Pool:\r\n\t\t\t\tFresno State Aquatics...
# 10  Primary Pool:\r\n\t\t\t\tTracy High School\r\n...
# 11  Primary Pool:\r\n\t\t\t\tAmerican River Colleg...
# 12  Primary Pool:\r\n\t\t\t\tAmerican River Colleg...
# 13  Primary Pool:\r\n\t\t\t\tCentral Unified Aquat...
# 14  Primary Pool:\r\n\t\t\t\tSunnyside High School...
# 15  Primary Pool:\r\n\t\t\t\tClovis West High Scho...
# 16  Primary Pool:\r\n\t\t\t\tDe La Salle High Scho...
# 17  Primary Pool:\r\n\t\t\t\tUC Davis Schaal Aquat...
# 18  Primary Pool:\r\n\t\t\t\tDixon Community Pool\...
# 19  Primary Pool:\r\n\t\t\t\tFresno High School\r\...
#
#                                               club_id club_zone
# 0   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 31318\n \r...     10008
# 1   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 30234\n \r...     10008
# 2   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 23883\n \r...     10008
# 3   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 85\n \r\n\...     10008
# 4   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 21063\n \r...     10008
# 5   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 19513\n \r...     10008
# 6   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 16629\n \r...     10008
# 7   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 31674\n \r...     10008
# 8   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 16120\n \r...     10008
# 9   \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 31612\n \r...     10008
# 10  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 33546\n \r...     10008
# 11  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 26152\n \r...     10008
# 12  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 34421\n \r...     10008
# 13  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 34208\n \r...     10008
# 14  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 1675\n \r\...     10008
# 15  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 47\n \r\n\...     10008
# 16  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 33982\n \r...     10008
# 17  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 79\n \r\n\...     10008
# 18  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 18313\n \r...     10008
# 19  \r\n\t\t\t\t \r\n\t\t\t\t\tClub ID: 34492\n \r...     10008

# %%
clubs_df.to_csv('club_info.csv')
